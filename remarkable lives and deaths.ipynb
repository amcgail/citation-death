# %%
import sys, os; sys.path.insert(0, os.path.join(_dh[0].split("post 5-12-2020")[0], "post 5-12-2020\git repository _ citation-deaths"))
from knowknow import *
register_notebook(_dh[0], "nothing")

# %%
database_name = 'sociology-wos'
dtype='ta'
birth_key='first'
definitions_of_death = ['death_1','rebirth_1_3']
#definitions_of_death = ['death1']

# %%
# Parameters
database_name = "sociology-wos"
dtype = "fa"
birth_key = "first"

# %%
# constructing a template for plotting
plot_args = {"database":database_name, "overwrite":True,"ctype":dtype,"cols":3,"rows_per_group":3}
plot_args['yearly_prop'] = False

# %%
filename_modifiers = [dtype, database_name]

# %%
if plot_args['yearly_prop']:
    filename_modifiers.append("proportional")

# %%
print(plot_args)
# Out:
# {'database': 'sociology-wos', 'overwrite': True, 'ctype': 'fa', 'cols': 3, 'rows_per_group': 3, 'yearly_prop': False}

# %%
if dtype=='t' and False: # no longer needed
    plot_args.update(dict(
        print_names=lambda t: "-".join(t),
    ))
    
if dtype=='c':
    plot_args.update(dict(
        print_names=lambda t: " ".join(t.split("|")).title(),
    ))
    
if 'jstor' in database_name:
    # dataset limitations
    
    plot_args.update(dict(
        xlim_display=(1965,2015),
        xlim_data=(1970,2010),
        cols=6
    ))
    
if 'jstor' in database_name:
    # dataset limitations
    
    plot_args.update(dict(
        xlim_display=(1965,2015),
        xlim_data=(1970,2010),
        cols=6
    ))

# %%
top1 = load_variable("%s.%s.top1" % (database_name,dtype))
ysum = load_variable("%s.%s.ysum" % (database_name,dtype))

# %%
top1.columns
# Out:
# Index(['rebirth_5_6', 'rebirth_2_20', 'maxcount', 'rebirth_5_4', 'rebirth_5_5',
#        'total', 'rebirth_5_8', 'rebirth_1_10', 'death_1', 'rebirth_2_5',
#        'death_3', 'death_2', 'rebirth_0_10', 'rebirth_5_10', 'name',
#        'rebirth_3_3', 'maxprop', 'rebirth_5_2', 'death_0', 'death_5',
#        'rebirth_0_5', 'maxcounty', 'rebirth_1_5', 'rebirth_3_10',
#        'rebirth_3_5', 'rebirth_5_20', 'rebirth_5_1', 'last', 'rebirth_0_3',
#        'rebirth_3_20', 'rebirth_2_3', 'rebirth_5_3', 'maxpropy', 'totalprop',
#        'rebirth_2_10', 'rebirth_5_0', 'rebirth_1_20', 'rebirth_5_9',
#        'rebirth_0_20', 'first', 'rebirth_5_7', 'rebirth_1_3'],
#       dtype='object')

# %%
14/159
# Out:
# 0.0880503144654088

# %%
top1.shape
# Out:
# (222, 42)

# %%
for deathk in sorted([x for x in top1.columns if 'death_' in x or 'rebirth_' in x]):
    c = np.sum(~np.isnan(top1[deathk]))
    print("%d (%0.2f%%) have a nonnull %s" %(
        c,
        100*c / top1.shape[0],
        deathk
    ))
# Out:
# 122 (54.95%) have a nonnull death_0
# 128 (57.66%) have a nonnull death_1
# 151 (68.02%) have a nonnull death_2
# 169 (76.13%) have a nonnull death_3
# 180 (81.08%) have a nonnull death_5
# 0 (0.00%) have a nonnull rebirth_0_10
# 0 (0.00%) have a nonnull rebirth_0_20
# 11 (4.95%) have a nonnull rebirth_0_3
# 9 (4.05%) have a nonnull rebirth_0_5
# 0 (0.00%) have a nonnull rebirth_1_10
# 0 (0.00%) have a nonnull rebirth_1_20
# 12 (5.41%) have a nonnull rebirth_1_3
# 7 (3.15%) have a nonnull rebirth_1_5
# 1 (0.45%) have a nonnull rebirth_2_10
# 0 (0.00%) have a nonnull rebirth_2_20
# 32 (14.41%) have a nonnull rebirth_2_3
# 8 (3.60%) have a nonnull rebirth_2_5
# 2 (0.90%) have a nonnull rebirth_3_10
# 0 (0.00%) have a nonnull rebirth_3_20
# 41 (18.47%) have a nonnull rebirth_3_3
# 13 (5.86%) have a nonnull rebirth_3_5
# 0 (0.00%) have a nonnull rebirth_5_0
# 0 (0.00%) have a nonnull rebirth_5_1
# 5 (2.25%) have a nonnull rebirth_5_10
# 0 (0.00%) have a nonnull rebirth_5_2
# 0 (0.00%) have a nonnull rebirth_5_20
# 52 (23.42%) have a nonnull rebirth_5_3
# 0 (0.00%) have a nonnull rebirth_5_4
# 21 (9.46%) have a nonnull rebirth_5_5
# 0 (0.00%) have a nonnull rebirth_5_6
# 0 (0.00%) have a nonnull rebirth_5_7
# 0 (0.00%) have a nonnull rebirth_5_8
# 0 (0.00%) have a nonnull rebirth_5_9

# %% [markdown]
# # visualize a random 100 top1% lives

# %%
database_name
# Out:
# 'sociology-wos'

# %%
definitions_of_death = ['death_1','rebirth_3_5','death_3','death_5']

# %%
from random import sample
toplot = [x for x in sample(list(top1.get("name")), 72)]

# %%
toplot = sorted(toplot, key=lambda x: ysum[x][birth_key])

# %%
def get_name(x):
    sp = x.split("_")
    if len(sp) == 2: # death
        return sp[-1]
    if len(sp) == 3:
        return "R"# % sp[-1]

# %%
plot_args.update(dict(
    alltop = toplot,
    myname = "100lives big (%s)" % ",".join( str(x) for x in filename_modifiers ), 
    markers={
        t: { 
            ysum[t][dk]:get_name(dk) # last character of a death key is the number,
            for dk in definitions_of_death 
            if ysum[t][dk] is not None # only deaths that happened
        }
        for t in toplot        
    },ctype=dtype
))

plot_count_series( **plot_args )
# Out:
# Loaded keys: dict_keys(['fa.fy', 'fy'])
# Available keys: ['a', 'c', 'c.c', 'c.fj', 'c.fy', 'c.fy.j', 'fa', 'fa.c', 'fa.fj', 'fa.fj.fy', 'fa.fy', 'ffa', 'ffa.c', 'ffa.fj', 'ffa.fy', 'fj', 'fj.fy', 'fj.ta', 'fj.ty', 'fy', 'fy.ta', 'fy.ty', 'ta', 'ty', 'ty.ty']
# hart, h
# winch, r
# riemer, s
# wallin, p
# hatt, p
# caplow, t
# reiss, a
# straus, m
# babchuk, n
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# davis, j
# vandenberghe, p
# curtis, r
# smith, r
# cutright, p
# perrucci, r
# morris, r
# photiadis, j
# segal, b
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# goldstein, s
# phillips, d
# farley, r
# murvar, v
# kandel, d
# israel, j
# treiman, d
# summers, g
# rogers, d
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# butler, j
# booth, a
# gove, w
# richardson, j
# hazelrigg, l
# hindelang, m
# hood, r
# webster, m
# weigert, a
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# lewis, j
# marshall, h
# brewer, j
# turner, j
# roof, w
# taylor, r
# alwin, d
# hagan, j
# sigelman, l
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# beck, e
# huber, j
# lemert, c
# murphy, j
# murdock, s
# hannan, m
# kelly, w
# hunt, j
# frisbie, w
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# hill, k
# smith, s
# hunt, l
# baker, p
# brinkerhoff, m
# tinsley, h
# freudenburg, w
# stack, s
# lichter, d
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# heaton, t
# mirowsky, j
# kessler, r
# everett, m
# clogg, c
# mcallister, i
# carroll, g
# south, s
# messner, s
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'

# %% [markdown]
# # unremarkable lives before 2000

# %%
from random import sample

definitions_of_death = ['death_0','rebirth_0_5','death_3','death_5']

toplot = sample([x for x in ysum if ysum[x]['first'] < 2000], 72)
toplot = sorted(toplot, key=lambda x: ysum[x]['first'])

plot_args.update(dict(
    alltop = toplot,
    myname = "100lives unremarkable (%s)" % ",".join( str(x) for x in filename_modifiers ), 
    markers={
        t: { 
            ysum[t][dk]:get_name(dk) # last character of a death key is the number,
            for dk in definitions_of_death 
            if ysum[t][dk] is not None # only deaths that happened
        }
        for t in toplot        
    },
))

plot_count_series(**plot_args)
# Out:
# Loaded keys: dict_keys(['fa.fy', 'fy'])
# Available keys: ['a', 'c', 'c.c', 'c.fj', 'c.fy', 'c.fy.j', 'fa', 'fa.c', 'fa.fj', 'fa.fj.fy', 'fa.fy', 'ffa', 'ffa.c', 'ffa.fj', 'ffa.fy', 'fj', 'fj.fy', 'fj.ta', 'fj.ty', 'fy', 'fy.ta', 'fy.ty', 'ta', 'ty', 'ty.ty']
# useem, j
# wallin, p
# hochbaum, g
# cutright, p
# bidwell, c
# dibble, v
# simon, w
# turk, a
# benvenuti, b
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# goldscheider, c
# richardson, j
# doreian, p
# dunlap, r
# mckennell, a
# hartnagel, t
# marks, s
# thomas, b
# villemez, w
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# williams, k
# mills, e
# cherlin, a
# massey, g
# molnar, j
# ditton, j
# reed, m
# moore, g
# eder, d
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# barnes, d
# baldwin, j
# kleiber, d
# brooks, a
# agnew, r
# manning, r
# hammitt, w
# martin, s
# fox, m
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# lennon, m
# maguire, b
# faust, k
# hickox, m
# fitzgerald, r
# siegel, j
# vining, j
# mooney, l
# lichtenstein, p
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# becker, g
# polinard, j
# foster, g
# steinberg, r
# emmison, m
# swedberg, r
# hultsman, j
# kim, d
# frone, m
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# harris, s
# nakhaie, m
# holland, s
# chen, x
# sanchez, l
# harris, k
# jarman, j
# goldsmith, a
# wallace, c
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# gallagher, s
# hinrichs, c
# edwards, k
# jamieson, r
# antaki, c
# grattet, r
# semino, e
# guo, g
# leung, k
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'

# %% [markdown]
# # visualize a random 100 top1% death1s

# %%
from random import sample

definitions_of_death = ['death_0','death_1','rebirth_3_5','death_3','death_5']

toplot = [x for x in top1.get("name") if ysum[x]['death_1']]

print("%s/%s" % (len(toplot), len(top1.get("name"))))

shuffle(toplot)
toplot = toplot[:72]

toplot = sorted(toplot, key=lambda x: ysum[x][birth_key])


plot_args.update(dict(
    alltop = toplot,
    myname = "100lives dead1 (%s)" % ",".join( str(x) for x in filename_modifiers ), 
    markers={
        t: { 
            ysum[t][dk]:get_name(dk) # last character of a death key is the number,
            for dk in definitions_of_death 
            if ysum[t][dk] is not None # only deaths that happened
        }
        for t in toplot        
    },
))

plot_count_series(**plot_args)
# Out:
# 128/222
# Loaded keys: dict_keys(['fa.fy', 'fy'])
# Available keys: ['a', 'c', 'c.c', 'c.fj', 'c.fy', 'c.fy.j', 'fa', 'fa.c', 'fa.fj', 'fa.fj.fy', 'fa.fy', 'ffa', 'ffa.c', 'ffa.fj', 'ffa.fy', 'fj', 'fj.fy', 'fj.ta', 'fj.ty', 'fy', 'fy.ta', 'fy.ty', 'ta', 'ty', 'ty.ty']
# hart, h
# lundberg, g
# chapin, f
# becker, h
# winch, r
# riemer, s
# cahnman, w
# porterfield, a
# christensen, h
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# wallin, p
# form, w
# hatt, p
# caplow, t
# babchuk, n
# blau, p
# bell, w
# dornbusch, s
# jones, f
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# fliegel, f
# dinitz, s
# vandenberghe, p
# lieberson, s
# middleton, r
# zald, m
# cutright, p
# perrucci, r
# photiadis, j
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# rushing, w
# bonjean, c
# phillips, d
# werts, c
# rogers, d
# kandel, d
# erickson, m
# wilkinson, k
# morgan, d
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# hazelrigg, l
# gray, l
# berk, r
# weigert, a
# horan, p
# featherman, d
# hope, k
# marshall, h
# useem, m
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# roof, w
# clemente, f
# felson, m
# levine, d
# peek, c
# sigelman, l
# alwin, d
# levinson, r
# buttel, f
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# lyson, t
# driedger, l
# tamney, j
# bulmer, m
# frisbie, w
# griffin, l
# greenberg, d
# baker, p
# krohn, m
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'
# szafran, r
# tinsley, h
# verdaasdonk, h
# kluegel, j
# bainbridge, w
# kessler, r
# lorence, j
# clogg, c
# martin, s
# Saving to 'G:\My Drive\projects\qualitative analysis of literature\post 5-12-2020\citation-death\figures'

# %%
# The above plot is much better.

if False:

    # visualize a random 100 top1% death2s

    from random import sample

    toplot = list(top1[~np.isnan(top1.death2)].get("name"))
    shuffle(toplot)
    toplot = toplot[:100]

    toplot = sorted(toplot, key=lambda x: ysum[x][birth_key])

    plot_count_series(
        toplot, 
        database_name, 
        myname="%s.100 big death2s of <b>%s</b> (%s)" % (dtype, database_name), 
        overwrite=True, 
        markers={}, 
        cysum=ysum, 
        ctype=dtype
    )

    # visualize 100 top1% death3s

    from random import sample

    toplot = list(top1[~np.isnan(top1.death3)].get("name"))
    shuffle(toplot)
    toplot = toplot[:100]
    toplot = sorted(toplot, key=lambda x: ysum[x][birth_key])

    plot_count_series(
        toplot, 
        database_name, 
        myname="%s.100 big death3s of <b>%s</b> (%s)" % (dtype, database_name), 
        overwrite=True, 
        markers={t:[ysum[t]['death3']] for t in toplot}, 
        cysum=ysum, 
        ctype=dtype
    )

    from random import sample

    toplot = list(top1[~np.isnan(top1.death5)].get("name"))
    shuffle(toplot)
    toplot = toplot[:100]
    toplot = sorted(toplot, key=lambda x: ysum[x][birth_key])

    plot_count_series(
        toplot, 
        database_name, 
        myname="%s.100 big death5s of <b>%s</b> (%s)" % (dtype, database_name), 
        overwrite=True, 
        markers={t:[ysum[t]['death5']] for t in toplot}, 
        cysum=ysum, 
        ctype=dtype
    )
